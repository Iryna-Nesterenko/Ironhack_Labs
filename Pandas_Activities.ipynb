# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

pd.options.display.max_rows = 100
## Install xlrd package to load Excel files
#!conda install openpyxl
#!conda install xlrd

# %% [markdown]
# # Activity 1 (Monday)
#
# -Aggregate data into one Data Frame using Pandas. Pay attention that files may have different names for the same column. therefore, make sure that you unify the columns names before concating them.
# Standardizing header names
# -Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data
# -Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of open complaints ). Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.
# clean the number of open complaints and extract the middle number which is changing between records. pay attention that the number of open complaints is a categorical feature.
# Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns
# Removing duplicates

# %%
file1 = pd.read_csv('/Users/irenewalken/Documents/GitHub/IH_RH_DA_FT_AUG_2022/Class_Materials/Case_Studies/Customer_Analysis_Case_Study/Data/file1.csv')
file2 = pd.read_csv('/Users/irenewalken/Documents/GitHub/IH_RH_DA_FT_AUG_2022/Class_Materials/Case_Studies/Customer_Analysis_Case_Study/Data/file2.csv')
file3 = pd.read_csv('/Users/irenewalken/Documents/GitHub/IH_RH_DA_FT_AUG_2022/Class_Materials/Case_Studies/Customer_Analysis_Case_Study/Data/file3.csv')

# %%
file2.rename(columns = {'ST':'State', 'GENDER':'Gender'}, inplace = True)
file1.rename(columns = {'ST':'State','GENDER':'Gender'}, inplace = True)

# %%
file1
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file1 = file1[['State','Gender','Education','Customer Lifetime Value','Income','Monthly Premium Auto','Number of Open Complaints','Policy Type','Vehicle Class','Total Claim Amount']]
file2 = file2[['State','Gender','Education','Customer Lifetime Value','Income','Monthly Premium Auto','Number of Open Complaints','Policy Type','Vehicle Class','Total Claim Amount']]
file3 = file3[['State','Gender','Education','Customer Lifetime Value','Income','Monthly Premium Auto','Number of Open Complaints','Policy Type','Vehicle Class','Total Claim Amount']]

# %%
file2
# Out:
#           State Gender Education Customer Lifetime Value  Income  \
# 0       Arizona      F  Bachelor              323912.47%   16061
# 1    California      F    Master              462680.11%   79487
# 2    California      F   College              899704.02%   54230
# 3        Oregon      F   College             2580706.30%   71210
# 4       Arizona      F   College              380812.21%   94903
# ..          ...    ...       ...                     ...     ...
# 991     Arizona      M    Master              847141.75%   63513
# 992     Arizona      F   College              543121.91%   58161
# 993      Nevada      F   College              568964.41%   83640
# 994  California      F    Master              368672.38%       0
# 995  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                      88                    1/0/00   Personal Auto
# ...

# %%
file3
# Out:
#            State Gender             Education  Customer Lifetime Value  \
# 0     Washington      M  High School or Below              3479.137523
# 1        Arizona      M                Master              2502.637401
# 2         Nevada      F              Bachelor              3265.156348
# 3     California      F  High School or Below              4455.843406
# 4     California      M  High School or Below              7704.958480
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#       Income  Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# ...

# %%
def customer_data():
   
    return pd.concat([file1,file2,file3], axis=0)

# %%
df = customer_data()

# %%
df
# Out:
#            State Gender             Education Customer Lifetime Value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      9137 non-null   object
#  1   Gender                     9015 non-null   object
#  2   Education                  9137 non-null   object
#  3   Customer Lifetime Value    9130 non-null   object
#  4   Income                     9137 non-null   float64
#  5   Monthly Premium Auto       9137 non-null   float64
#  6   Number of Open Complaints  9137 non-null   object
#  7   Policy Type                9137 non-null   object
#  8   Vehicle Class              9137 non-null   object
#  9   Total Claim Amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 1.0+ MB

# %%
df['Customer Lifetime Value']= df['Customer Lifetime Value'].apply(lambda x: float(x.strip('%'))/100 if isinstance(x,str) else x)#remove the percentage from the customer lifetime value

# %%
df
# Out:
#            State Gender             Education  Customer Lifetime Value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor              6979.535900
# 2         Nevada      F              Bachelor             12887.431700
# 3     California      M              Bachelor              7645.861800
# 4     Washington      M  High School or Below              5363.076500
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor             23405.987980
# 7066  California      F               College              3096.511217
# 7067  California      M              Bachelor              8163.890428
# 7068  California      M               College              7524.442436
# 7069  California      M               College              2611.836866
#
#        Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
df['Customer Lifetime Value'] =  pd.to_numeric(df['Customer Lifetime Value'], errors='coerce') #transform it to float

# %%
df['Customer Lifetime Value']= df['Customer Lifetime Value'].apply(lambda x: float(round(x,0)) if isinstance(x,(int,float)) else x)#transform to int and nan stay float

# %%
df["Number of Open Complaints"].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', nan, 0,
#        2, 3, 1, 5, 4], dtype=object)

# %%
df["Number of Open Complaints"] = df["Number of Open Complaints"].apply(lambda x: float(x.split('/')[1]) if isinstance(x,str) else x)

# %%
df["Number of Open Complaints"].unique()
# Out:
# array([ 0.,  2.,  1.,  3.,  5.,  4., nan])

# %%
df.tail(120)
# Out:
#            State Gender             Education  Customer Lifetime Value  \
# 6950  California      M               College                   2130.0
# 6951  California      F  High School or Below                   2907.0
# 6952  California      M  High School or Below                   4916.0
# 6953  California      M                Master                   5068.0
# 6954  California      F              Bachelor                   7822.0
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor                  23406.0
# 7066  California      F               College                   3097.0
# 7067  California      M              Bachelor                   8164.0
# 7068  California      M               College                   7524.0
# 7069  California      M               College                   2612.0
#
#        Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df["State"].value_counts()
# Out:
# California    3032
# Oregon        2601
# Arizona       1630
# Nevada         882
# Washington     768
# Cali           120
# AZ              74
# WA              30
# Name: State, dtype: int64

# %%
df["Education"].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College',
#        'Bachelors', 'Doctor', nan], dtype=object)

# %%
df["Education"] = df["Education"].replace("Bachelors","Bachelor")

# %%
df["State"]= df["State"].replace(["WA","AZ","Cali"], ["Washington", "Arizona","California"])

# %%
df["Gender"].value_counts()
# Out:
# F         4560
# M         4368
# Male        40
# female      30
# Femal       17
# Name: Gender, dtype: int64

# %%
df["Gender"]=df["Gender"].replace(["Male","female","Femal"],["M","F","F"])

# %%
df = df.drop_duplicates()

# %% [markdown]
# # Activity 2 (Tuesday)
#
# Replacing null values – Replace missing values with means of the column (for numerical columns). Pay attention that the Income feature for instance has 0s which is equivalent to null values. (We assume here that there is no such income with 0 as it refers to missing values) Hint: numpy.nan is considered of float64 data type.
# Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central
# (Optional) Standardizing the data – Use string functions to standardize the text data (lower case)

# %%
df["Customer Lifetime Value"].mean()
# Out:
# 7987.89286124842

# %%
income_mean = df["Income"].mean()
income_mean
# Out:
# 37711.61509303928

# %%
df["Monthly Premium Auto"].mean()
# Out:
# 110.5947622329428

# %%
df["Number of Open Complaints"].median()
# Out:
# 0.0

# %%
df["Customer Lifetime Value"]=df["Customer Lifetime Value"].fillna(df["Customer Lifetime Value"].mean())
# Out:
# /var/folders/dc/mkf8yrbx1ds4p7h5pty0xs600000gn/T/ipykernel_20546/103278075.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Customer Lifetime Value"]=df["Customer Lifetime Value"].fillna(df["Customer Lifetime Value"].mean())

# %%
df["Income"] = df["Income"].fillna(income_mean)
# Out:
# /var/folders/dc/mkf8yrbx1ds4p7h5pty0xs600000gn/T/ipykernel_20546/4142689644.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Income"] = df["Income"].fillna(income_mean)

# %%
df["Income"] = df["Income"].replace(0,income_mean)
# Out:
# /var/folders/dc/mkf8yrbx1ds4p7h5pty0xs600000gn/T/ipykernel_20546/3109548469.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Income"] = df["Income"].replace(0,income_mean)

# %%
df
# Out:
#            State Gender             Education  Customer Lifetime Value  \
# 0     Washington    NaN                Master              7987.892861
# 1        Arizona      F              Bachelor              6980.000000
# 2         Nevada      F              Bachelor             12887.000000
# 3     California      M              Bachelor              7646.000000
# 4     Washington      M  High School or Below              5363.000000
# ...          ...    ...                   ...                      ...
# 7064  California      F               College              4100.000000
# 7065  California      M              Bachelor             23406.000000
# 7067  California      M              Bachelor              8164.000000
# 7068  California      M               College              7524.000000
# 7069  California      M               College              2612.000000
#
#             Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df["Number of Open Complaints"]=df["Number of Open Complaints"].fillna(df["Number of Open Complaints"].median())
# Out:
# /var/folders/dc/mkf8yrbx1ds4p7h5pty0xs600000gn/T/ipykernel_20546/1477468377.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Number of Open Complaints"]=df["Number of Open Complaints"].fillna(df["Number of Open Complaints"].median())

# %%
df["Number of Open Complaints"].value_counts()
# Out:
# 0.0    6897
# 1.0     972
# 2.0     367
# 3.0     276
# 4.0     141
# 5.0      54
# Name: Number of Open Complaints, dtype: int64

# %%
df["Customer Lifetime Value"]=df["Customer Lifetime Value"].fillna(df["Customer Lifetime Value"].mean())
# Out:
# /var/folders/dc/mkf8yrbx1ds4p7h5pty0xs600000gn/T/ipykernel_20546/103278075.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Customer Lifetime Value"]=df["Customer Lifetime Value"].fillna(df["Customer Lifetime Value"].mean())

# %%
df["Customer Lifetime Value"].value_counts()
# Out:
# 2491.0     9
# 5569.0     9
# 2472.0     9
# 2619.0     9
# 2396.0     9
#           ..
# 7551.0     1
# 9939.0     1
# 14962.0    1
# 5276.0     1
# 7524.0     1
# Name: Customer Lifetime Value, Length: 5636, dtype: int64

# %%
df["Monthly Premium Auto"]=df["Monthly Premium Auto"].fillna(df["Monthly Premium Auto"].mean())
# Out:
# /var/folders/dc/mkf8yrbx1ds4p7h5pty0xs600000gn/T/ipykernel_20546/4097825810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Monthly Premium Auto"]=df["Monthly Premium Auto"].fillna(df["Monthly Premium Auto"].mean())

# %%
df["Monthly Premium Auto"].value_counts()
# Out:
# 65.0     327
# 71.0     291
# 66.0     286
# 73.0     280
# 69.0     275
#         ...
# 178.0      1
# 204.0      1
# 281.0      1
# 275.0      1
# 286.0      1
# Name: Monthly Premium Auto, Length: 210, dtype: int64

# %%
df["Gender"] = df["Gender"].fillna("U")
# Out:
# /var/folders/dc/mkf8yrbx1ds4p7h5pty0xs600000gn/T/ipykernel_20546/252275096.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gender"] = df["Gender"].fillna("U")

# %%
df["Gender"].unique()
# Out:
# array(['U', 'F', 'M'], dtype=object)

# %%
df["State"].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', nan],
#       dtype=object)

# %%
df["State"] = df["State"].replace(["Washington","Arizona","Nevada","California","Oregon"], ["East","Central","Central","West Region","North West"])
# Out:
# /var/folders/dc/mkf8yrbx1ds4p7h5pty0xs600000gn/T/ipykernel_20546/2186006164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["State"] = df["State"].replace(["Washington","Arizona","Nevada","California","Oregon"], ["East","Central","Central","West Region","North West"])

# %%
df.rename(columns={'State': 'Zones'}, inplace=True)
# Out:
# /var/folders/dc/mkf8yrbx1ds4p7h5pty0xs600000gn/T/ipykernel_20546/635719036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'State': 'Zones'}, inplace=True)

# %%
df
# Out:
#             Zones Gender             Education  Customer Lifetime Value  \
# 0            East      U                Master              7987.892861
# 1         Central      F              Bachelor              6980.000000
# 2         Central      F              Bachelor             12887.000000
# 3     West Region      M              Bachelor              7646.000000
# 4            East      M  High School or Below              5363.000000
# ...           ...    ...                   ...                      ...
# 7064  West Region      F               College              4100.000000
# 7065  West Region      M              Bachelor             23406.000000
# 7067  West Region      M              Bachelor              8164.000000
# 7068  West Region      M               College              7524.000000
# 7069  West Region      M               College              2612.000000
#
#             Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
# df['Zones'] = df['Zones'].str.lower()
# df['Education'] = df['Education'].str.lower()
# df['Policy Type'] = df['Policy Type'].str.lower()
# df['Vehicle Class'] = df['Vehicle Class'].str.lower()
# df['Gender'] = df['Gender'].str.lower()

# %%
df = df.applymap(lambda x: x.lower() if isinstance(x,str) else x)

# %%
df
# Out:
#             Zones Gender             Education  Customer Lifetime Value  \
# 0            east      u                master              7987.892861
# 1         central      f              bachelor              6980.000000
# 2         central      f              bachelor             12887.000000
# 3     west region      m              bachelor              7646.000000
# 4            east      m  high school or below              5363.000000
# ...           ...    ...                   ...                      ...
# 7064  west region      f               college              4100.000000
# 7065  west region      m              bachelor             23406.000000
# 7067  west region      m              bachelor              8164.000000
# 7068  west region      m               college              7524.000000
# 7069  west region      m               college              2612.000000
#
#             Income  Monthly Premium Auto  Number of Open Complaints  \
# ...
